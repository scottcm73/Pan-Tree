# %%
import pandas as pd
import os
import numpy as np


order_products_edit = pd.read_csv('../Resources/order_products_wm.csv')
order_products = pd.DataFrame(order_products_edit)
order_products["trash"] = order_products["q_left"].where(order_products["q_left"] <= 1 , np.random.randint(0, 5, len(order_products)))
order_products.to_csv(r'../Resources\order_products_wm_edit_df.csv', index = False)
order_products.head(50)
# Out:
#     order_id  product_id  quantity  q_left  trash  product_id.1  \
# 0          2       33120         1       1      1         33120
# 1          2       28985         2       2      2         28985
# 2          2        9327         3       3      0          9327
# 3          2       45918         4       4      2         45918
# 4          2       30035         5       5      3         30035
# 5          2       17794         6       6      4         17794
# 6          2       40141         7       7      4         40141
# 7          2        1819         8       8      2          1819
# 8          2       43668         9       9      2         43668
# 9          3       33754         1       1      1         33754
# 10         3       24838         2       2      1         24838
# 11         3       17704         3       3      0         17704
# 12         3       21903         4       4      3         21903
# 13         3       17668         5       5      1         17668
# ...
